# %%
! pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Definir la llave para descargar archivos
# !echo '{"username":"marcehoyos5","key":"409fee39c45dc847f15c175a626368fa"}' > /root/.kaggle/kaggle.json

# %%
#Descargar el dataset
! kaggle datasets download imakash3011/customer-personality-analysis
# Out:
# ...
# customer-personality-analysis.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
#Descomprimir archivo
! unzip customer-personality-analysis.zip
# Out:
# Archive:  customer-personality-analysis.zip
# replace marketing_campaign.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: marketing_campaign.csv

# %%
from google.colab import drive  
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
#Cargar archivo al drive
# !cp '/content/marketing_campaign.csv' '/content/gdrive/MyDrive/proyecto-integrador-grupo1/proyecto-integrador-data'
